# %%
import numpy as np
import pandas as pd
import mplfinance as mpf
import pandas_datareader as web
import datetime
# %matplotlib inline

# %%
start= datetime.datetime(2021,1,1)
end= datetime.datetime(2021,5,23)

# %%
google= web.DataReader('TSLA','yahoo', start, end)
google
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-12-31  718.719971  691.119995  699.989990  705.669983  49649900
# 2021-01-04  744.489990  717.190002  719.460022  729.770020  48638200
# 2021-01-05  740.840027  719.200012  723.659973  735.109985  32245200
# 2021-01-06  774.000000  749.099976  758.489990  755.979980  44700000
# 2021-01-07  816.989990  775.200012  777.630005  816.039978  51498900
# ...                ...         ...         ...         ...       ...
# 2021-05-17  589.729980  561.200012  575.549988  576.830017  32390400
# 2021-05-18  596.250000  563.380005  568.000000  577.869995  36830600
# 2021-05-19  566.210022  546.979980  552.549988  563.460022  39578400
# 2021-05-20  588.849976  571.070007  575.000000  586.780029  30821100
# 2021-05-21  596.679993  580.000000  596.109985  580.880005  25943600
#
#              Adj Close
# Date
# 2020-12-31  705.669983
# 2021-01-04  729.770020
# 2021-01-05  735.109985
# 2021-01-06  755.979980
# ...

# %%
google.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
mpf.plot(google, style='yahoo', volume= True, type='candlestick', title= "Google 2021")
