# %%
import numpy as np
import pandas as pd
import mplfinance as mpf
import datetime
# %matplotlib inline

# %%
df= pd.read_csv('Nepse_2021.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 280 entries, 2020-01-01 to 2021-05-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       280 non-null    float64
#  1   Low        280 non-null    float64
#  2   Open       280 non-null    float64
#  3   Close      280 non-null    float64
#  4   Volume     280 non-null    float64
#  5   Adj Close  280 non-null    float64
# dtypes: float64(6)
# memory usage: 15.3 KB

# %%
mpf.plot(df, volume= True, type='candlestick', title= "NEPSE 2020-2021", figsize=(20,20), mav=(9,20))
